# %%
from keras.models import Model
from keras.layers import *

# %%
model=Model(inputs=i,outputs=[output_1,output_2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model=Model(inputs=input,outputs=[output_1,output_2])
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/utils/tracking.py:27, in no_automatic_dependency_tracking.<locals>.wrapper(*args, **kwargs)
#      24 @wraps(fn)
#      25 def wrapper(*args, **kwargs):
#      26     with DotNotTrackScope():
# ---> 27         return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/models/functional.py:120, in Functional.__init__(self, inputs, outputs, name, **kwargs)
#     118 for x in flat_inputs:
#     119     if not isinstance(x, backend.KerasTensor):
# --> 120         raise ValueError(
#     121             "All `inputs` values must be KerasTensors. Received: "
# ...

# %%
input=Input((3,))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Input=Input((3,))
#
# TypeError: 'KerasTensor' object is not callable

# %%
hidden_1=Dense(32,activation='relu')(Input)
hidden_2=Dense(32,activation='relu')(hidden_1)

output_1=Dense(1,activation='sigmoid')(hidden_2)
output_2=Dense(1,activation='linear')(hidden_2)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined
